# %% [markdown]
# # Reading JSON File From Given Storage

# %%
import pandas as pd

# %%
df = pd.read_json("shrikant.json")
df
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Reading JSON File From Other Storage

# %%
import pandas as pd
file = pd.read_json("C:/Users/Lenovo/Videos/season1.json")
file
# Out:
#            Game Of Thrones S01E01 Winter Is Coming.srt  \
# 1                                           Easy, boy.
# 10             Our orders were to track the wildlings.
# 100                       - Right. Give it here. - No!
# 101                               Put away your blade.
# 102  - I take orders from your father, not you. - P...
# ..                                                 ...
# 771                                                NaN
# 772                                                NaN
# 773                                                NaN
# 774                                                NaN
# 775                                                NaN
#
#     Game Of Thrones S01E02 The Kingsroad.srt  \
# 1                  You need to drink, child.
# 10         The Dothraki believe that one day
# 100                     Such a little thing.
# 101                 A bird without feathers.
# 102          They came to take his body away
# ...

# %% [markdown]
# # Reading File From Mysql(database)

# %%
 # !pip install pymysql

# %%
import pymysql as mysql

# %%
con =mysql.connect(host='localhost',user='root',password='root',database='practice')

# %%
pd =pd.read_sql_query('select * from student',con)
pd
# Out:
#    ID     name       address
# 0   1     shri        parali
# 1   2    dilip        mondha
# 2   3   akshay          bank
# 3   4  shrawan  gandhimarket
# 4   5   gaurav          beed
# 5   6     atul          pune

# %%
# For storing in CSV
pd.to_csv('database.csv')

# %%
# For storing in json format
pd.to_json('data.json')

# %% [markdown]
# # Reading Data From Sqlite(Database)

# %%
import sqlite3
import pandas as pd
db = sqlite3.connect('C:/Users/Lenovo/sqliteDB/tectonic.db')
df = pd.read_sql_query("select * from studentinfo",db)
df
# Out:
#    id      name gender
# 0   1  shrikant      m
# 1   2   kaushal      m
# 2   3  ashutosh      m
# 3   4      atul      m
